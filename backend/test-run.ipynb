# %% [markdown]
# # Teste do módulo backend
#
# Executa a construção e os testes do módulo backend para validar a implementação.

# %%
import os
import subprocess

os.chdir('/workspaces/react_native/backend')
result = subprocess.run(['mvn', '-q', 'test'], capture_output=True, text=True)
print('returncode=', result.returncode)
print(result.stdout)
print(result.stderr)
